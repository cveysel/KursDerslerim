# %% [markdown]
# **SUPPORT VECTOR MACHİNE**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("10-diamonds.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.shape
# Out:
# (53940, 11)

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# carat         0
# cut           0
# color         0
# clarity       0
# depth         0
# table         0
# price         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %%
df.drop("Unnamed: 0", axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53940 non-null  float64
#  1   cut      53940 non-null  object
#  2   color    53940 non-null  object
#  3   clarity  53940 non-null  object
#  4   depth    53940 non-null  float64
#  5   table    53940 non-null  float64
#  6   price    53940 non-null  int64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.1+ MB

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
# x y z 0 lar var min de normalde olmaması lazım. buna bir bakılacak.

# %%
(df["x"]==0).sum()
# Out:
# np.int64(8)

# %%
(df["y"]==0).sum()
# Out:
# np.int64(7)

# %%
(df["z"]==0).sum()
# Out:
# np.int64(20)

# %%
df.drop(df[df["x"]==0].index, inplace=True)

# %%
(df["x"]==0).sum()
# Out:
# np.int64(0)

# %%
df.drop(df[df["y"]==0].index, inplace=True)
df.drop(df[df["z"]==0].index, inplace=True)

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53920.000000  53920.000000  53920.000000  53920.000000  53920.000000
# mean       0.797698     61.749514     57.456834   3930.993231      5.731627
# std        0.473795      1.432331      2.234064   3987.280446      1.119423
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5323.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  53920.000000  53920.000000
# mean       5.734887      3.540046
# std        1.140126      0.702530
# min        3.680000      1.070000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %%
sns.pairplot(df)

# %%
sns.scatterplot(x=df["x"], y=df["price"])
# Out:
# <Axes: xlabel='x', ylabel='price'>

# %%
sns.scatterplot(x=df["y"], y=df["price"])
# Out:
# <Axes: xlabel='y', ylabel='price'>

# %%
sns.scatterplot(x=df["z"], y=df["price"])
# Out:
# <Axes: xlabel='z', ylabel='price'>

# %%
sns.scatterplot(x=df["depth"], y=df["price"])
# Out:
# <Axes: xlabel='depth', ylabel='price'>

# %%
sns.scatterplot(x=df["table"], y=df["price"])
# Out:
# <Axes: xlabel='table', ylabel='price'>

# %%
print("veri sayısı: ",len(df["x"]),"\nx outliersiz veri sayısı: ",len(df[((df["x"]<10))]))
# Out:
# veri sayısı:  53920
# x outliersiz veri sayısı:  53914

# %%
print("veri sayısı: ",len(df["y"]),"\ny outliersiz veri sayısı: ",len(df[((df["y"]<20))]))
# Out:
# veri sayısı:  53920
# y outliersiz veri sayısı:  53918

# %%
print("veri sayısı: ",len(df["z"]),"\nz outliersiz veri sayısı: ",len(df[((df["z"]<10) & (df["z"]>2))]))
# Out:
# veri sayısı:  53920
# z outliersiz veri sayısı:  53916

# %%
print("veri sayısı: ",len(df["depth"]),"\nDEPTH outliersiz veri sayısı: ",len(df[((df["depth"]<75) & (df["depth"]>45))]))
# Out:
# veri sayısı:  53920
# DEPTH outliersiz veri sayısı:  53914

# %%
print("veri sayısı: ",len(df["table"]),"\ntable outliersiz veri sayısı: ",len(df[((df["table"]<72) & (df["table"]>48))]))
# Out:
# veri sayısı:  53920
# table outliersiz veri sayısı:  53911

# %% [markdown]
# Yukarıdakiler çıkarılacak outlier datalar. böylece daha iyi sonuç veren model geliştirilecek.

# %%
df = df[((df["x"]<10))]
df = df[((df["y"]<20))]
df = df[((df["z"]<10) & (df["z"]>2))]
df = df[((df["depth"]<75) & (df["depth"]>45))]
df = df[((df["table"]<72) & (df["table"]>48))]

# %%
len(df["table"])
# Out:
# 53895

# %%
df.describe()
# Out:
#               carat         depth         table         price             x  \
# count  53895.000000  53895.000000  53895.000000  53895.000000  53895.000000
# mean       0.797249     61.749383     57.454881   3929.327526      5.730991
# std        0.472371      1.419324      2.219180   3985.283262      1.118489
# min        0.200000     50.800000     49.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    949.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2400.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5321.500000      6.540000
# max        3.670000     73.600000     71.000000  18823.000000      9.860000
#
#                   y             z
# count  53895.000000  53895.000000
# mean       5.732842      3.539129
# std        1.110394      0.690795
# min        3.680000      2.060000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.035000
# ...

# %%
sns.scatterplot(x=df["depth"], y=df["price"])
# Out:
# <Axes: xlabel='depth', ylabel='price'>

# %% [markdown]
# Sıra kategorik değişkenlerde

# %%
df["cut"].value_counts()
# Out:
# cut
# Ideal        21542
# Premium      13777
# Very Good    12078
# Good          4902
# Fair          1596
# Name: count, dtype: int64

# %%
df["color"].value_counts()
# Out:
# color
# G    11281
# E     9791
# F     9535
# H     8294
# D     6773
# I     5417
# J     2804
# Name: count, dtype: int64

# %%
df["clarity"].value_counts()
# Out:
# clarity
# SI1     13058
# VS2     12249
# SI2      9183
# VS1      8164
# VVS2     5066
# VVS1     3654
# IF       1790
# I1        731
# Name: count, dtype: int64

# %%
X = df.drop("price",axis = 1)
y =df["price"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=15)

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 53895 entries, 0 to 53939
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   carat    53895 non-null  float64
#  1   cut      53895 non-null  object
#  2   color    53895 non-null  object
#  3   clarity  53895 non-null  object
#  4   depth    53895 non-null  float64
#  5   table    53895 non-null  float64
#  6   price    53895 non-null  int64
#  7   x        53895 non-null  float64
#  8   y        53895 non-null  float64
#  9   z        53895 non-null  float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 4.5+ MB

# %%
for col in ["cut","color","clarity"]:
    X_train[col]= label_encoder.fit_transform(X_train[col])
    X_test[col]= label_encoder.transform(X_test[col])

# %%
X_train["cut"].value_counts()
# Out:
# cut
# 2    16261
# 3    10296
# 4     8994
# 1     3663
# 0     1207
# Name: count, dtype: int64

# %%
X_test["cut"].value_counts()
# Out:
# cut
# 2    5281
# 3    3481
# 4    3084
# 1    1239
# 0     389
# Name: count, dtype: int64

# %%
X_train.describe()
# Out:
#               carat           cut         color       clarity         depth  \
# count  40421.000000  40421.000000  40421.000000  40421.000000  40421.000000
# mean       0.795905      2.549393      2.589100      3.839019     61.751971
# std        0.471873      1.026162      1.701124      1.725923      1.414136
# min        0.200000      0.000000      0.000000      0.000000     51.000000
# 25%        0.400000      2.000000      1.000000      2.000000     61.000000
# 50%        0.700000      2.000000      3.000000      4.000000     61.800000
# 75%        1.040000      3.000000      4.000000      5.000000     62.500000
# max        3.650000      4.000000      6.000000      7.000000     73.600000
#
#               table             x             y             z
# count  40421.000000  40421.000000  40421.000000  40421.000000
# mean      57.448707      5.727702      5.729554      3.537241
# std        2.216360      1.117840      1.109909      0.690530
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
linear = LinearRegression()
linear.fit(X_train_scaled,y_train)
y_pred = linear.predict(X_test_scaled)
mae = mean_absolute_error(y_pred, y_test)
mse = mean_squared_error(y_pred, y_test)
r2 = r2_score(y_pred, y_test)
print("\nLinear Regression Model")
print("MAE: ",mae)
print("MSE: ",mse)
print("R2: ",r2)
plt.scatter(y_test, y_pred, color = "red")
# Out:
# Linear Regression Model
# MAE:  861.0709301235212
# MSE:  1795983.8972399672
# R2:  0.8741737235651005

# %%
from sklearn.svm import SVR

# %%
svr = SVR()
svr.fit(X_train_scaled,y_train)
y_pred = svr.predict(X_test_scaled)
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)
print("\nLinear Regression Model")
print("MAE: ",mae)
print("MSE: ",mse)
print("R2: ",r2)
plt.scatter(y_test,y_pred)
# Out:
# Linear Regression Model
# MAE:  1400.1032300110523
# MSE:  8129831.590324066
# R2:  0.49504240323084914

# %%
#hyperparameter tuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {
    "kernel": ["linear", "rbf"],
    "C":[0.1,1,10,100,1000],
    "gamma":["scale","auto"]
}

# %%
grid = GridSearchCV(estimator= SVR(), param_grid= param_grid, n_jobs= -1, cv= 5, verbose= 3)
grid.fit(X_train_scaled,y_train)
# verbose işlem hakkında bilgi veriyor
# cv cross validation
# n_jobs =-1 ise işlemci gücünü tamamen burayay aktarıyor
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# GridSearchCV(cv=5, estimator=SVR(), n_jobs=-1,
#              param_grid={'C': [0.1, 1, 10, 100, 1000],
#                          'gamma': ['scale', 'auto'],
#                          'kernel': ['linear', 'rbf']},
#              verbose=3)

# %%
y_pred = grid.predict(X_test_scaled)

# %%
grid.best_params_
# Out:
# {'C': 1000, 'gamma': 'auto', 'kernel': 'rbf'}

# %%
mae = mean_absolute_error(y_test,y_pred)
mse = mean_squared_error(y_test,y_pred)
r2 = r2_score(y_test,y_pred)
print("\nLinear Regression Model")
print("MAE: ",mae)
print("MSE: ",mse)
print("R2: ",r2)
plt.scatter(y_test,y_pred)
# Out:
# Linear Regression Model
# MAE:  483.3947200850603
# MSE:  910012.6994611188
# R2:  0.9434775713809126
